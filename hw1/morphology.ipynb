# %%
import xml.etree.ElementTree as ET

# %%
tree = ET.parse('dict.xml')
root = tree.getroot()

# %%
CONSTANT_PREFIXES = [
    "авиа",
    "авто",
    "аква",
    "анти",
    "анти-",
    "антропо",
    "архи",
    "арт",
    "арт-",
    "астро",
    "аудио",
    "аэро",
    "без",
    "бес",
    "био",
    "вело",
    "взаимо",
    "вне",
    "внутри",
    "видео",
    "вице-",
    "вперед",
    "впереди",
    "гекто",
    "гелио",
    "гео",
    "гетеро",
    "гига",
    "гигро",
    "гипер",
    "гипо",
    "гомо",
    "дву",
    "двух",
    "де",
    "дез",
    "дека",
    "деци",
    "дис",
    "до",
    "евро",
    "за",
    "зоо",
    "интер",
    "инфра",
    "квази",
    "квази-",
    "кило",
    "кино",
    "контр",
    "контр-",
    "космо",
    "космо-",
    "крипто",
    "лейб-",
    "лже",
    "лже-",
    "макро",
    "макси",
    "макси-",
    "мало",
    "меж",
    "медиа",
    "медиа-",
    "мега",
    "мета",
    "мета-",
    "метео",
    "метро",
    "микро",
    "милли",
    "мини",
    "мини-",
    "моно",
    "мото",
    "много",
    "мульти",
    "нано",
    "нарко",
    "не",
    "небез",
    "недо",
    "нейро",
    "нео",
    "низко",
    "обер-",
    "обще",
    "одно",
    "около",
    "орто",
    "палео",
    "пан",
    "пара",
    "пента",
    "пере",
    "пиро",
    "поли",
    "полу",
    "после",
    "пост",
    "пост-",
    "порно",
    "пра",
    "пра-",
    "пред",
    "пресс-",
    "противо",
    "противо-",
    "прото",
    "псевдо",
    "псевдо-",
    "радио",
    "разно",
    "ре",
    "ретро",
    "ретро-",
    "само",
    "санти",
    "сверх",
    "сверх-",
    "спец",
    "суб",
    "супер",
    "супер-",
    "супра",
    "теле",
    "тетра",
    "топ-",
    "транс",
    "транс-",
    "ультра",
    "унтер-",
    "штаб-",
    "экзо",
    "эко",
    "эндо",
    "эконом-",
    "экс",
    "экс-",
    "экстра",
    "экстра-",
    "электро",
    "энерго",
    "этно",
]

# %%
def max_common(word, forms):
    n = len(word)
    i = 0
    while (i < n):
        is_ok = True
        for form in forms:
            if len(form) > i and form[i] == word[i]:
                continue
            else:
                is_ok = False
                break
        if not is_ok:
            break
        i += 1    
        
    return word[:i]

# %%
speech_part_dict = {
    "NOUN" : "S",
    "ADJF" : "A",
    "ADJS" : "A",
    "COMP" : "A",
    "VERB" : "V",
    "INFN" : "V",
    "PRTF" : "V",
    "PRTS" : "V",
    "GRND" : "V",
    "NUMR" : "NI",
    "ADVB" : "ADV",
    "NPRO" : "NI",
    "PRED" : "S",
    "PREP" : "PR",
    "CONJ" : "CONJ",
    "PRCL" : "ADV",
    "INTJ" : "ADV",
    
}

# %%
class Lemma:
    def __init__(self, id_, word, word_forms, speech_part):
        self.moved = -1
        self.word = word.lower().replace('ё', 'е') 
        self.speech_part = speech_part
        self.id = id_
        
        self.end_list = [''] * len(word_forms)
        self.pref_list = [''] * len(word_forms)
        
        word_forms_ = []
        for i in range(len(word_forms)):
            form = word_forms[i]
            if form.startswith('по') and not word.startswith('по'):
                form = word_forms[i][2:]
                self.pref_list[i] = 'по'
            if form.startswith('наи') and not word.startswith('наи'):
                form = word_forms[i][3:]
                self.pref_list[i] = 'наи'    
            word_forms_.append(form.lower().replace('ё', 'е'))
            
        self.stem = max_common(self.word, word_forms_)
        if (self.stem == ''):
            self.end_list = word_forms_
            return
        
        for i in range(len(word_forms_)):
            form = word_forms_[i]
            end = form.replace(self.stem, '', 1)
            self.end_list[i] = end
            #print(self.pref_list[i] + " _ " + self.stem + " _ " + end)

# %%
from tqdm import tqdm

# %%
lemma_id_to_lemma_dict = {}

# %%
for lemma in tqdm(root.find('lemmata')):
    word = lemma.find('l').get('t')
    #if ('-' in word):
     #   continue
    word_forms = []
    for form in lemma.findall('f'):
        word_forms.append(form.get('t'))
    speech_part = speech_part_dict[lemma.find('l').find('g').get('v')]
    id_ = lemma.get('id')
    parsed_lemma = Lemma(id_, word, word_forms, speech_part) 
    lemma_id_to_lemma_dict[id_] = parsed_lemma
    #if (parsed_lemma.stem in stem_to_lemma_dict.keys()):
    #    stem_to_lemma_dict[parsed_lemma.stem].append(parsed_lemma)
    #else:
    #    stem_to_lemma_dict[parsed_lemma.stem] = [parsed_lemma]
# Out:
# 100%|██████████| 391243/391243 [01:11<00:00, 5456.51it/s]

# %%
len(lemma_id_to_lemma_dict.keys())
# Out:
# 391243

# %%
def generate_word_forms_from_lemma(lemma):
    word_forms = []
    for i in range(len(lemma.end_list)):
        form = lemma.pref_list[i] + lemma.stem + lemma.end_list[i] 
        word_forms.append(form)
    return word_forms

# %%
def append_lemma(from_lemma, to_lemma):
    from_forms = generate_word_forms_from_lemma(from_lemma)
    to_forms = generate_word_forms_from_lemma(to_lemma)
    return Lemma(to_lemma.id, to_lemma.word, from_forms + to_forms, to_lemma.speech_part)

# %%
def move_lemma(from_lemma_id, to_lemma_id):
    while True:
        if lemma_id_to_lemma_dict[to_lemma_id].moved != -1:
            to_lemma_id = lemma_id_to_lemma_dict[to_lemma_id].moved
        else:
            break
    from_lemma = lemma_id_to_lemma_dict[from_lemma_id]
    from_lemma.moved = to_lemma_id
    to_lemma = lemma_id_to_lemma_dict[to_lemma_id]
    to_lemma = append_lemma(from_lemma, to_lemma)
    return from_lemma, to_lemma

# %%
EXCLUDED_LINK_TYPES = ['7', '21', '23', '27']
for link in tqdm(root.find('links')):
    from_ = link.get('to')
    to_ = link.get('from')
    type_ = link.get('type')
    #print(from_ == "6")
    #break
    if type_ not in EXCLUDED_LINK_TYPES:
        lemma_id_to_lemma_dict[from_], lemma_id_to_lemma_dict[to_] = move_lemma(from_, to_)
# Out:
# 100%|██████████| 258488/258488 [01:24<00:00, 3051.39it/s]

# %%
stem_to_lemma_dict = {}
for lemma_id in tqdm(lemma_id_to_lemma_dict.keys()):
    lemma = lemma_id_to_lemma_dict[lemma_id]
    if lemma.word == "побывал" :
        print("FFFFFF" + str(lemma.moved))
    if not lemma.moved == -1:
        continue
    if lemma.stem in stem_to_lemma_dict.keys():
        stem_to_lemma_dict[lemma.stem].append(lemma)
    else:
        stem_to_lemma_dict[lemma.stem] = [lemma]
# Out:
#  64%|██████▍   | 250640/391243 [00:31<00:02, 58785.18it/s]
# FFFFFF241938
# 100%|██████████| 391243/391243 [00:33<00:00, 11706.23it/s]

# %%
example = "Все Гришины одноклассники уже побывали за границей, он был чуть ли не единственным, кого не вывозили никуда дальше Красной Пахры."

# %%
def remove_prefix(word):
    word = word.lower()
    longest_prefix = ""
    for prefix in CONSTANT_PREFIXES:
        if word.startswith(prefix) and len(prefix) > len(longest_prefix):
            longest_prefix = prefix
    if longest_prefix:
        prf, wrd = remove_prefix(word.replace(longest_prefix, '', 1))
        return longest_prefix + prf, wrd
    return '', word

# %%
def process_word(prefix, stem, end):
    if stem in stem_to_lemma_dict.keys():
        lemmas = stem_to_lemma_dict[stem]
        #if stem == 'политическ':
        #    print(lemmas[0].end_list)
    
        for lemma in lemmas:
            for i in range(len(lemma.end_list)):
                #if stem == 'политическ' and i == 7:
                    #print(lemma.pref_list[i] + " " + prefix)
                    #print(lemma.pref_list[i] == prefix)
                if prefix == lemma.pref_list[i] and end == lemma.end_list[i]:
                    #if stem == 'политическ':
                    #    print("!!!")
                    return lemma
    return None

# %%
def process_word_extracted_prefix(prefix, word):
    i = 1
    while (i <= len(word)):
        #print(prefix + " " + word[:i] + " " + word[i:])
        lmm = process_word(prefix, word[:i], word[i:])
        #if (word[:i] == 'политическ'):
        #    print(lmm.word)
        if lmm:
            return lmm
        i += 1
    return process_word(prefix, '', word)

# %%
exp = "был"

# %%
INPUT_FILE_NAME = "dataset.txt"
OUTPUT_FILE_NAME = "output.txt"

# %%
results_all = ""
with open(INPUT_FILE_NAME, 'r') as fin:
    for line in tqdm(fin):
        results = ""
        for word in line.split(' '):
            pure_word = word.replace(',', '').replace('.', '').replace('?', '').replace('!', '').replace('\n','')
            if pure_word:
                constant_prefix, pure_word_no_pref = remove_prefix(pure_word)
        #print(constant_prefix + " " + pure_word_no_pref)
                if pure_word_no_pref.startswith('по'):
                    lmm = process_word_extracted_prefix('по', pure_word_no_pref[2:]) 
                    if lmm:
                        results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                        continue
                if pure_word_no_pref.startswith('наи'):
                    lmm = process_word_extracted_prefix('наи', pure_word_no_pref[3:]) 
                    if lmm:
                        results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                        continue   
        #print("12345")
        #print(pure_word_no_pref)
                lmm = process_word_extracted_prefix('', pure_word_no_pref) 
        #if pure_word_no_pref == 'политическая':
            #print("AAAA" + lmm.word)
        #print(stem_to_lemma_dict[lmm.stem][0].id) 
        #print(stem_to_lemma_dict[lmm.stem][1].id)    
                if lmm:
                    results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                    continue
                pure_word_no_pref = pure_word.lower()
                constant_prefix = ""
        #print("753245")
        #print(pure_word_no_pref)
    
                if pure_word_no_pref.startswith('по'):
                    lmm = process_word_extracted_prefix('по', pure_word_no_pref[2:]) 
                    if lmm:
                        results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                        continue
                if pure_word_no_pref.startswith('наи'):
                    lmm = process_word_extracted_prefix('наи', pure_word_no_pref[3:]) 
                    if lmm:
                        results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                        continue   
        #print("7777")        
                lmm = process_word_extracted_prefix('', pure_word_no_pref) 
        #print("$$$$" + lmm.word)
                if lmm:
                    results = results + pure_word + "{" + constant_prefix + lmm.word + "=" + lmm.speech_part + "} "
                    continue    
                results = results + pure_word + "{" + constant_prefix + pure_word_no_pref + "=ADV} "
        results_all = results_all + results[:-1] + "\n"
results_all = results_all[:-1]
# Out:
# 200it [00:06, 31.55it/s]

# %%
with open(OUTPUT_FILE_NAME, 'w') as fout:
    fout.write(results_all)

# %%
print('Все{весь=NI} Гришины{гришин=A} \n одноклассники{одноклассник=S} уже{уже=ADV} побывали{побывать=V} за{за=PR} границей{граница=S} он{он=NI} был{быть=V} чуть{чуть=ADV} ли{ли=ADV} не{не=ADV} единственным{единственный=A} кого{кто=NI} не{не=ADV} вывозили{вывозить=V} никуда{никуда=NI} дальше{далеко=ADV} Красной{красный=A} Пахры{Пахра=S}')
# Out:
# Все{весь=NI} Гришины{гришин=A}
#  одноклассники{одноклассник=S} уже{уже=ADV} побывали{побывать=V} за{за=PR} границей{граница=S} он{он=NI} был{быть=V} чуть{чуть=ADV} ли{ли=ADV} не{не=ADV} единственным{единственный=A} кого{кто=NI} не{не=ADV} вывозили{вывозить=V} никуда{никуда=NI} дальше{далеко=ADV} Красной{красный=A} Пахры{Пахра=S}

# %%
for lmm in stem_to_lemma_dict[""]:
    print(lmm.word + " " + str(lmm.end_list))
# Out:
# александрович ['саныч', 'саныча', 'санычу', 'саныча', 'санычем', 'саныче', 'санычи', 'санычей', 'санычам', 'санычей', 'санычами', 'санычах', 'александровна', 'александровны', 'александровне', 'александровну', 'александровной', 'александровне', 'александровны', 'александровен', 'александровнам', 'александровен', 'александровнами', 'александровнах', 'александрович', 'александровича', 'александровичу', 'александровича', 'александровичем', 'александровиче', 'александровичи', 'александровичей', 'александровичам', 'александровичей', 'александровичами', 'александровичах']
# большой ['больше', 'больше', 'велик', 'велика', 'велико', 'велики', 'велика', 'большой', 'большого', 'большому', 'большого', 'большой', 'большим', 'большом', 'большая', 'большой', 'большой', 'большую', 'большой', 'большою', 'большой', 'большое', 'большого', 'большому', 'большое', 'большим', 'большом', 'большие', 'больших', 'большим', 'больших', 'большие', 'большими', 'больших']
# быть ['будучи', 'бывши', 'бывший', 'бывшего', 'бывшему', 'бывшего', 'бывший', 'бывшим', 'бывшем', 'бывшая', 'бывшей', 'бывшей', 'бывшую', 'бывшей', 'бывшею', 'бывшей', 'бывшее', 'бывшего', 'бывшему', 'бывшее', 'бывшим', 'бывшем', 'бывшие', 'бывших', 'бывшим', 'бывших', 'бывшие', 'бывшими', 'бывших', 'есть', 'суть', 'есть', 'был', 'была', 'было', 'были', 'буду', 'будем', 'будешь', 'будете', 'будет', 'будут', 'будем', 'будь', 'будьте', 'е', 'есмь', 'быть']
# вероятный ['невероятнейший', 'невероятнейшего', 'невероятнейшему', 'невероятнейшего', 'невероятнейший', 'невероятнейшим', 'невероятнейшем', 'невероятнейшая', 'невероятнейшей', 'невероятнейшей', 'невероятнейшую', 'невероятнейшей', 'невероятнейшею', 'невероятнейшей', 'невероятнейшее', 'невероятнейшего', 'невероятнейшему', 'невероятнейшее', 'невероятнейшим', 'невероятнейшем', 'невероятнейшие', 'невероятнейших', 'невероятнейшим', 'невероятнейших', 'невероятнейшие', 'невероятнейшими', 'невероятнейших', 'вероятнее', 'вероятней', 'вероятнее', 'вероятней', 'вероятен', 'вероятна', 'вероятно', 'вероятны', 'вероятнейший', 'вероятнейшего', 'вероятнейшему', 'вероятнейшего', 'вероятнейший', 'вероятнейшим', 'вероятнейшем', 'вероятнейшая', 'вероятнейшей', 'вероятнейшей', 'вероятнейшую', 'вероятнейшей', 'вероятнейшею', 'вероятнейшей', 'вероятнейшее', 'вероятнейшего', 'вероятнейшему', 'вероятнейшее', 'вероятнейшим', 'вероятнейшем', 'вероятнейшие', 'вероятнейших', 'вероятнейшим', 'вероятнейших', 'вероятнейшие', 'вероятнейшими', 'вероятнейших', 'вероятный', 'вероятного', 'вероятному', 'вероятного', 'вероятный', 'вероятным', 'вероятном', 'вероятная', 'вероятной', 'вероятной', 'вероятную', 'вероятной', 'вероятною', 'вероятной', 'вероятное', 'вероятного', 'вероятному', 'вероятное', 'вероятным', 'вероятном', 'вероятные', 'вероятных', 'вероятным', 'вероятных', 'вероятные', 'вероятными', 'вероятных']
# год ['год', 'года', 'году', 'год', 'годом', 'годе', 'году', 'года', 'годы', 'лета', 'годов', 'лет', 'годам', 'года', 'годы', 'годами', 'годах', 'году', 'гг', 'гг', 'гг', 'гг', 'гг', 'гг', 'летам', 'лета', 'летами', 'летах']
# идти ['идя', 'шедши', 'шедший', 'шедшего', 'шедшему', 'шедшего', 'шедший', 'шедшим', 'шедшем', 'шедшая', 'шедшей', 'шедшей', 'шедшую', 'шедшей', 'шедшею', 'шедшей', 'шедшее', 'шедшего', 'шедшему', 'шедшее', 'шедшим', 'шедшем', 'шедшие', 'шедших', 'шедшим', 'шедших', 'шедшие', 'шедшими', 'шедших', 'идущий', 'идущего', 'идущему', 'идущего', 'идущий', 'идущим', 'идущем', 'идущая', 'идущей', 'идущей', 'идущую', 'идущей', 'идущею', 'идущей', 'идущее', 'идущего', 'идущему', 'идущее', 'идущим', 'идущем', 'идущие', 'идущих', 'идущим', 'идущих', 'идущие', 'идущими', 'идущих', 'иду', 'идем', 'идешь', 'идете', 'идет', 'идут', 'шел', 'шла', 'шло', 'шли', 'идем', 'идемте', 'иди', 'идите', 'идти']
# идтись ['шлось', 'идется', 'идтись']
# класть ['кладя', 'клавши', 'клавший', 'клавшего', 'клавшему', 'клавшего', 'клавший', 'клавшим', 'клавшем', 'клавшая', 'клавшей', 'клавшей', 'клавшую', 'клавшей', 'клавшею', 'клавшей', 'клавшее', 'клавшего', 'клавшему', 'клавшее', 'клавшим', 'клавшем', 'клавшие', 'клавших', 'клавшим', 'клавших', 'клавшие', 'клавшими', 'клавших', 'кладущий', 'кладущего', 'кладущему', 'кладущего', 'кладущий', 'кладущим', 'кладущем', 'кладущая', 'кладущей', 'кладущей', 'кладущую', 'кладущей', 'кладущею', 'кладущей', 'кладущее', 'кладущего', 'кладущему', 'кладущее', 'кладущим', 'кладущем', 'кладущие', 'кладущих', 'кладущим', 'кладущих', 'кладущие', 'кладущими', 'кладущих', 'кладу', 'кладем', 'кладешь', 'кладете', 'кладет', 'кладут', 'клал', 'клала', 'клало', 'клали', 'ложу', 'ложим', 'ложишь', 'ложите', 'ложит', 'ложат', 'ложут', 'клади', 'кладите', 'класть']
# много ['больше', 'больше', 'много']
# мы ['мы', 'нас', 'нам', 'нас', 'нами', 'нас']
# мыслимый ['мыслимее', 'мыслимей', 'мыслимее', 'мыслимей', 'мыслим', 'мыслима', 'мыслимо', 'мыслимы', 'немыслимейший', 'немыслимейшего', 'немыслимейшему', 'немыслимейшего', 'немыслимейший', 'немыслимейшим', 'немыслимейшем', 'немыслимейшая', 'немыслимейшей', 'немыслимейшей', 'немыслимейшую', 'немыслимейшей', 'немыслимейшею', 'немыслимейшей', 'немыслимейшее', 'немыслимейшего', 'немыслимейшему', 'немыслимейшее', 'немыслимейшим', 'немыслимейшем', 'немыслимейшие', 'немыслимейших', 'немыслимейшим', 'немыслимейших', 'немыслимейшие', 'немыслимейшими', 'немыслимейших', 'мыслимый', 'мыслимого', 'мыслимому', 'мыслимого', 'мыслимый', 'мыслимым', 'мыслимом', 'мыслимая', 'мыслимой', 'мыслимой', 'мыслимую', 'мыслимой', 'мыслимою', 'мыслимой', 'мыслимое', 'мыслимого', 'мыслимому', 'мыслимое', 'мыслимым', 'мыслимом', 'мыслимые', 'мыслимых', 'мыслимым', 'мыслимых', 'мыслимые', 'мыслимыми', 'мыслимых']
# нквд ['энкаведе', 'энкаведе', 'энкаведе', 'энкаведе', 'энкаведе', 'энкаведе', 'нквд', 'нквд', 'нквд', 'нквд', 'нквд', 'нквд']
# он ['он', 'его', 'него', 'ему', 'нему', 'его', 'него', 'им', 'ним', 'нем']
# она ['она', 'ее', 'нее', 'ней', 'ей', 'ней', 'ее', 'нее', 'ей', 'ею', 'ней', 'нею', 'ней', 'ея']
# слать ['слан', 'слана', 'слано', 'сланы', 'шля', 'слав', 'славши', 'сланный', 'сланного', 'сланному', 'сланного', 'сланный', 'сланным', 'сланном', 'сланная', 'сланной', 'сланной', 'сланную', 'сланной', 'сланною', 'сланной', 'сланное', 'сланного', 'сланному', 'сланное', 'сланным', 'сланном', 'сланные', 'сланных', 'сланным', 'сланных', 'сланные', 'сланными', 'сланных', 'славший', 'славшего', 'славшему', 'славшего', 'славший', 'славшим', 'славшем', 'славшая', 'славшей', 'славшей', 'славшую', 'славшей', 'славшею', 'славшей', 'славшее', 'славшего', 'славшему', 'славшее', 'славшим', 'славшем', 'славшие', 'славших', 'славшим', 'славших', 'славшие', 'славшими', 'славших', 'шлющий', 'шлющего', 'шлющему', 'шлющего', 'шлющий', 'шлющим', 'шлющем', 'шлющая', 'шлющей', 'шлющей', 'шлющую', 'шлющей', 'шлющею', 'шлющей', 'шлющее', 'шлющего', 'шлющему', 'шлющее', 'шлющим', 'шлющем', 'шлющие', 'шлющих', 'шлющим', 'шлющих', 'шлющие', 'шлющими', 'шлющих', 'шлю', 'шлем', 'шлешь', 'шлете', 'шлет', 'шлют', 'слал', 'слала', 'слало', 'слали', 'шли', 'шлите', 'слать']
# слать ['слан', 'слана', 'слано', 'сланы', 'шля', 'слав', 'славши', 'сланный', 'сланного', 'сланному', 'сланного', 'сланный', 'сланным', 'сланном', 'сланная', 'сланной', 'сланной', 'сланную', 'сланной', 'сланною', 'сланной', 'сланное', 'сланного', 'сланному', 'сланное', 'сланным', 'сланном', 'сланные', 'сланных', 'сланным', 'сланных', 'сланные', 'сланными', 'сланных', 'славший', 'славшего', 'славшему', 'славшего', 'славший', 'славшим', 'славшем', 'славшая', 'славшей', 'славшей', 'славшую', 'славшей', 'славшею', 'славшей', 'славшее', 'славшего', 'славшему', 'славшее', 'славшим', 'славшем', 'славшие', 'славших', 'славшим', 'славших', 'славшие', 'славшими', 'славших', 'шлющий', 'шлющего', 'шлющему', 'шлющего', 'шлющий', 'шлющим', 'шлющем', 'шлющая', 'шлющей', 'шлющей', 'шлющую', 'шлющей', 'шлющею', 'шлющей', 'шлющее', 'шлющего', 'шлющему', 'шлющее', 'шлющим', 'шлющем', 'шлющие', 'шлющих', 'шлющим', 'шлющих', 'шлющие', 'шлющими', 'шлющих', 'шлю', 'шлем', 'шлешь', 'шлете', 'шлет', 'шлют', 'слал', 'слала', 'слало', 'слали', 'шли', 'шлите', 'слать']
